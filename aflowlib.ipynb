# %% [markdown]
# # aflow duke university
# https://rosenbrockc.github.io/aflow/
#
# 下载的example：
# https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAu/1/aflowlib.json

# %%
# 保存html文件，以https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/1/为例
# 后续的文件格式肯定要调整，不处理数据了。
import subprocess
subprocess.Popen("curl -o aflowlib-AgAl-1 https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/1/", shell=True)
# Out:
# <Popen: returncode: None args: 'curl -o aflowlib-AgAl-1 https://aflowlib.duk...>

# %%
# 以https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/目录为例，自动下载下面的1057个链接。
from bs4 import BeautifulSoup


base_url = 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/'
# 手动下载base_url, 将'aflowlib_entries'和'<br>'之间的内容保存到AgAl.html
with open('AgAl.html', 'r') as html_file:
    content = html_file.read()
soup = BeautifulSoup(content, 'html.parser')

link_list = []
for link in soup.find_all('a'):
    link_list.append(''.join([base_url, link.get('href')]))

print(len(link_list))
# save link_list
with open('AgAl.csv', 'w') as link_file:
    write_content = '\n'.join(link_list)
    link_file.write(write_content)
# Out:
# 1057
# ['https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./1', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./2', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./3', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./4', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./5', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./6', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./7', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./8', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./9', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./10', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./11', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./12', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./13', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./14', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./15', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./16', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./17', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./18', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./19', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./20', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./21', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./22', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./23', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./24', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./25', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./26', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./27', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./28', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./29', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./58', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./59', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./60', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./61', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./62', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./63', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./64', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./65', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./66', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./67', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./68', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./69', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./70', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./71', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./72', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./73', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./74', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./75', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./76', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./77', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./78', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./79', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./80', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./81', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./82', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./83', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./84', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./85', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./86', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./115', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./116', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./117', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./118', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./119', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./120', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./121', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./122', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./123', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./124', 'https://aflowlib.duke.edu/AFLOWDATA/LIB2_WEB/AgAl/./1 ...
